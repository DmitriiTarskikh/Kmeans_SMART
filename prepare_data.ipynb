# %% [markdown]
# # Скачивание 1 квартала, уменьшение количества столбцов

# %%
# !pip install wget
import wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=29c1ac121f1126952ee157aec27b8241fa9c444076232b213c3a2e829ec6d160
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
wget.download('https://f001.backblazeb2.com/file/Backblaze-Hard-Drive-Data/data_Q1_2021.zip')
!7z x 'data_Q1_2021.zip' -o'./Q1'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 889786067 bytes (849 MiB)
#
# Extracting archive: data_Q1_2021.zip
# --
# Path = data_Q1_2021.zip
# Type = zip
# Physical Size = 889786067
#
# Everything is Ok
#
# Files: 180
# Size:       4942407507
# Compressed: 889786067

# %%
import pandas as pd
from pathlib import Path
import glob

# %%
directory = './Q1'
count = 0
for path in glob.iglob(f'{directory}/*.csv'):
  df = pd.read_csv(path)
  new_df=df[['date','serial_number','failure','smart_3_normalized','smart_5_normalized','smart_7_normalized','smart_195_normalized','smart_197_normalized','smart_199_normalized']]
  new_df.to_csv(path)

# %%
# !cat ./Q1/*.csv | uniq > Q1.csv
# !sed '/date/d' Q1.csv >> Q1_1.csv

# %%
# !cat /content/drive/MyDrive/knormal.txt >> Q1_2.csv
# !cat Q1_1.csv >> Q1_2.csv

# %%
!7z a -mx1 'Q1_2.zip' 'Q1_2.csv'
# !cp Q1_2.zip '/content/drive/MyDrive/knormalize'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive:
# 1 file, 924357524 bytes (882 MiB)
#
# Creating archive: Q1_2.zip
#
# Items to compress: 1
#
#  99% 1 + Q1_2.csv
# Files read from disk: 1
# Archive size: 175793505 bytes (168 MiB)
# Everything is Ok
